# %%
import requests
import json
from Config import api_key

# %%
import pandas as pd
import concurrent.futures
import time

# %% [markdown]
# # Get list of all files

# %%
#Synchronous solution - MUCH SLOWER
from IPython.display import clear_output
file_paths = []


empty = 0
for i in range(1, 10000):
    url = f'https://cchdo.ucsd.edu/api/v1/file/{i}'
    re = requests.get(url, headers = {"X-Authentication-Token": api_key})
    file_json = json.loads(re.text)
    if file_json['file_path'] == '':
        empty += 1
    else:
        file_paths.append(file_json['file_path'])
    clear_output(wait=True)
    print(str(i) + ' - ' +  str(empty))

# %%
file_paths

# %%
#Get list all file ids
url = 'https://cchdo.ucsd.edu/api/v1/file'
re = requests.get(url, headers = {"X-Authentication-Token": api_key})
raw_json = json.loads(re.text)
file_ids = [x['id'] for x in raw_json['files']]

# %%
file_metadata_urls = [f'https://cchdo.ucsd.edu/api/v1/file/{file_id}' for file_id in file_ids]

# %%
#Asynchronous solution
#Get all file metadata
out = []
CONNECTIONS = 100
TIMEOUT = 50

urls = file_metadata_urls

def load_url(url, timeout):
    re = requests.get(url, headers = {"X-Authentication-Token": api_key})
    if re.status_code >= 300:
        return ['ERROR', url, re.status_code]
    else:
        raw_json = json.loads(re.text)
        return raw_json

with concurrent.futures.ThreadPoolExecutor(max_workers=CONNECTIONS) as executor:
    future_to_url = (executor.submit(load_url, url, TIMEOUT) for url in urls)
    time1 = time.time()
    for future in concurrent.futures.as_completed(future_to_url):
        try:
            data = future.result()
        except Exception as exc:
            data = str(type(exc))
        finally:
            out.append(data)

            print(str(len(out)),end="\r")

    time2 = time.time()

print(f'Took {time2-time1:.2f} s')
# Out:
# Took 326.92 s

# %%
#Verify there are no errors
errors = [x for x in out if (not isinstance(x, dict))]
len(errors)
# Out:
# 0

# %%
with open('data.json', 'w') as outfile:
    json.dump(out, outfile)

# %%
with open('data.json', 'r') as f:
    out = json.load(f)

# %% [markdown]
# https://cchdo.ucsd.edu/api/v1/file/all Doesn't return file paths, is this intentional?

# %%
# #Get list of all cruises and their ids
# url = 'https://cchdo.ucsd.edu/api/v1/file/all'
# re = requests.get(url, headers = {"X-Authentication-Token": api_key})
# raw_json = json.loads(re.text)

# %%
#raw_json

# %% [markdown]
# ### Roles, data formats, and data types
#
# Is there a specific subset of this we want to check?
# Currently only pulling files where the `data_type` is `bottle` or `ctd`

# %%
set([x['role'] for x in out])
# Out:
# {'',
#  'ancillary',
#  'archive',
#  'dataset',
#  'hidden',
#  'intermediate',
#  'merged',
#  'product',
#  'raw',
#  'unprocessed'}

# %%
set([x['data_format'] for x in out])
# Out:
# {'',
#  'cf_netcdf',
#  'exchange',
#  'hrp_netcdf',
#  'joa_binary',
#  'matlab',
#  'ods',
#  'pdf',
#  'sbe_ascii_cnv',
#  'sbe_hex_xmlcon_24hz',
#  'text',
#  'whp_netcdf',
#  'woce'}

# %%
set([x['data_type'] for x in out])
# Out:
# {'',
#  'bottle',
#  'ctd',
#  'documentation',
#  'float',
#  'hrp',
#  'large_volume',
#  'summary',
#  'trace_metals'}

# %%
sum([x['file_size'] for x in out if x['data_format'] == 'exchange'])
# Out:
# 1947976580

# %%
exchange_urls = ['https://cchdo.ucsd.edu' + x['file_path'] for x in out if x['data_format'] == 'exchange']
exchange_urls
# Out:
# ['https://cchdo.ucsd.edu/data/45/pr16_2004b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/4/ar08_c_hy1.csv',
#  'https://cchdo.ucsd.edu/data/18/ais01_09AR20010101_hy1.csv',
#  'https://cchdo.ucsd.edu/data/11/64TR19900417_hy1.csv',
#  'https://cchdo.ucsd.edu/data/9/ar28_74CH19850120_ct1.zip',
#  'https://cchdo.ucsd.edu/data/181/ar16_e_hy1.csv',
#  'https://cchdo.ucsd.edu/data/190/33H420090412_ars20_ct1.zip',
#  'https://cchdo.ucsd.edu/data/90/58JH19980801_hy1.csv',
#  'https://cchdo.ucsd.edu/data/42/35MF20091219_hy1.csv',
#  'https://cchdo.ucsd.edu/data/56/35LL19910103_hy1.csv',
#  'https://cchdo.ucsd.edu/data/121/320620110219_hy1.csv',
#  'https://cchdo.ucsd.edu/data/224/33KI133_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/103/pr21_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/88/ir06_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/176/32MW105_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/162/06AQANTXIII4_hy1.csv',
#  'https://cchdo.ucsd.edu/data/92/pr02_i_hy1.csv',
#  'https://cchdo.ucsd.edu/data/220/pr17_n_ct1.zip',
#  'https://cchdo.ucsd.edu/data/219/33RO20131223_ct1.zip',
#  'https://cchdo.ucsd.edu/data/123/ar16_d_ct1.zip',
#  'https://cchdo.ucsd.edu/data/94/33KB20121202_ct1.zip',
#  'https://cchdo.ucsd.edu/data/204/49ZS19921203_hy1.csv',
#  'https://cchdo.ucsd.edu/data/143/p21_ct1.zip',
#  'https://cchdo.ucsd.edu/data/147/pr17_i_ct1.zip',
#  'https://cchdo.ucsd.edu/data/170/a23_ct1.zip',
#  'https://cchdo.ucsd.edu/data/49/OMEX2_hy1.csv',
#  'https://cchdo.ucsd.edu/data/200/p01w_1999a_hy1.csv',
#  'https://cchdo.ucsd.edu/data/246/ir01w_c_hy1.csv',
#  'https://cchdo.ucsd.edu/data/235/ar02_b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/237/325020080826_hy1.csv',
#  'https://cchdo.ucsd.edu/data/282/06MT45_3_hy1.csv',
#  'https://cchdo.ucsd.edu/data/279/33KB20120730_hy1.csv',
#  'https://cchdo.ucsd.edu/data/276/32MW057_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/313/33KB20120323_hy1.csv',
#  'https://cchdo.ucsd.edu/data/283/p14n_hy1.csv',
#  'https://cchdo.ucsd.edu/data/277/ar07e_f_ct1.zip',
#  'https://cchdo.ucsd.edu/data/295/ar12_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/301/32MW081_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/302/ir03_a_hy1.csv',
#  'https://cchdo.ucsd.edu/data/309/33H420100624_ct1.zip',
#  'https://cchdo.ucsd.edu/data/323/18HU20110506_ct1.zip',
#  'https://cchdo.ucsd.edu/data/344/33KI196_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/354/33KB20100806_ct1.zip',
#  'https://cchdo.ucsd.edu/data/374/31TC044_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/335/06MT200407_ct1.zip',
#  'https://cchdo.ucsd.edu/data/358/pr02_b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/398/ar07w_2003a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/393/sr03_c_hy1.csv',
#  'https://cchdo.ucsd.edu/data/368/33KB173_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/390/33KI129_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/391/33RR087_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/387/anas3_19810516_hy1.csv',
#  'https://cchdo.ucsd.edu/data/424/06AQ19990910_ct1.zip',
#  'https://cchdo.ucsd.edu/data/444/ar16_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/443/iss2_b_ct1.zip',
#  'https://cchdo.ucsd.edu/data/454/p10_49NZ20050525_ct1.zip',
#  'https://cchdo.ucsd.edu/data/462/pr18_h_ct1.zip',
#  'https://cchdo.ucsd.edu/data/459/pr17_i_hy1.csv',
#  'https://cchdo.ucsd.edu/data/472/p06c_hy1.csv',
#  'https://cchdo.ucsd.edu/data/473/pr18_l_ct1.zip',
#  'https://cchdo.ucsd.edu/data/494/p17c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/484/33KB20110718_hy1.csv',
#  'https://cchdo.ucsd.edu/data/490/pr05_b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/512/45CE20090206_hy1.csv',
#  'https://cchdo.ucsd.edu/data/493/pr01_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/500/a11_ct1.zip',
#  'https://cchdo.ucsd.edu/data/536/33KB170_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/520/64TR19900714_hy1.csv',
#  'https://cchdo.ucsd.edu/data/535/a07_ct1.zip',
#  'https://cchdo.ucsd.edu/data/501/ar07w_d_hy1.csv',
#  'https://cchdo.ucsd.edu/data/542/74JC20150110_hy1.csv',
#  'https://cchdo.ucsd.edu/data/551/18SN19970924_hy1.csv',
#  'https://cchdo.ucsd.edu/data/576/sr03_a_hy1.csv',
#  'https://cchdo.ucsd.edu/data/572/s04i_09ar20060102_ct1.zip',
#  'https://cchdo.ucsd.edu/data/577/33H420090207_ars20_ct1.zip',
#  'https://cchdo.ucsd.edu/data/590/ar07w_2004a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/603/33KI108_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/599/33KI145_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/604/p24_hy1.csv',
#  'https://cchdo.ucsd.edu/data/606/p14_49NZ20071122_hy1.csv',
#  'https://cchdo.ucsd.edu/data/627/32MW066_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/656/pr04_d_ct1.zip',
#  'https://cchdo.ucsd.edu/data/614/06AQ19870704_hy1.csv',
#  'https://cchdo.ucsd.edu/data/617/33KB174_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/634/33H420100621_ct1.zip',
#  'https://cchdo.ucsd.edu/data/685/06AQ19861226_ct1.zip',
#  'https://cchdo.ucsd.edu/data/677/ar08_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/679/iss1_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/701/06AQ20000730_ct1.zip',
#  'https://cchdo.ucsd.edu/data/694/iss3_d_ct1.zip',
#  'https://cchdo.ucsd.edu/data/661/ar07e_d_ct1.zip',
#  'https://cchdo.ucsd.edu/data/720/p16a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/719/pr16_dd_ct1.zip',
#  'https://cchdo.ucsd.edu/data/703/ar08_g_hy1.csv',
#  'https://cchdo.ucsd.edu/data/706/a12_06AQ20071128_hy1.csv',
#  'https://cchdo.ucsd.edu/data/702/ar19_d_hy1.csv',
#  'https://cchdo.ucsd.edu/data/748/pr17_e_ct1.zip',
#  'https://cchdo.ucsd.edu/data/735/33KB206_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/759/p16s_ct1.zip',
#  'https://cchdo.ucsd.edu/data/749/ar18_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/725/58JH19951108_hy1.csv',
#  'https://cchdo.ucsd.edu/data/770/33KB152_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/771/32MW092_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/801/33KB20130930_ct1.zip',
#  'https://cchdo.ucsd.edu/data/763/a10_hy1.csv',
#  'https://cchdo.ucsd.edu/data/806/pr04_b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/800/35A320010322_hy1.csv',
#  'https://cchdo.ucsd.edu/data/784/ar28_74CH19870424_ct1.zip',
#  'https://cchdo.ucsd.edu/data/798/35MF20080207_ct1.zip',
#  'https://cchdo.ucsd.edu/data/817/33KI119_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data
_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6495/pr19_e_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6521/p19a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6523/ar04_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6554/49NZ20120113_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6502/32MW095_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6534/32MW065_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6538/06AQ19831122_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6569/33KB183_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6560/pr16_l_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6571/32MW061_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6552/pr03n_c_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6568/pr11_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6594/a17_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6564/33KI156_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6606/33KI121_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6610/p09_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6598/33KI164_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6587/ir03_a_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6611/pr16_2003b_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6639/06AQ19950321_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6642/pr15_20060706_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6634/32MW075_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6652/a10_2003a_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6645/33KB181_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6643/33MW19920224_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6682/ar28_74LG19890805_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6677/33KI140_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6695/anas1_19810401_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6691/33KB197_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6712/a10_33RO20110926_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6711/pr16_b_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6716/atas3_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6709/18RD19990827_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6718/sr01_m_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6727/ar07e_d_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6760/ais01_09AR20020126_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6741/pr18_p_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6699/33KI120_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6738/pr15_2003b_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6750/33H420090813_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6775/33KB20100806_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6797/a16s_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6780/pr02_c_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6785/p31_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6856/33KB146_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6822/32EV19910328_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6847/pr18_j_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6808/33KB193_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6826/32MW067_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6824/33KB20110127_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6865/35MF19980818_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6843/p03e_49NZ20051031_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6886/33KB184_1_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6873/ar04_b_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6871/33KB177_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6860/33KB182_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6906/a07_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6880/33KI20100517_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6866/33KB188_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6878/33KB183_1_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6888/ar16_d_hy1.csv',
#  'https://cchdo.ucsd.edu/data/6876/pr18_i_ct1.zip',
#  'https://cchdo.ucsd.edu/data/6898/06AQ19860506_ct1.zip',
#  ...]

# %%
#Download files
out = []
errors = []
CONNECTIONS = 100
TIMEOUT = 50

urls = exchange_urls


def load_url(url, timeout):
    re = requests.get(url, allow_redirects=True, headers = {"X-Authentication-Token": api_key})
    if re.status_code >= 300:
        return ['ERROR', url, re.status_code]
    else:
        #Download file
        file_name = url.split('/')[-1]
        open('data/' + file_name, 'wb').write(re.content)
        return 'Success'

with concurrent.futures.ThreadPoolExecutor(max_workers=CONNECTIONS) as executor:
    future_to_url = (executor.submit(load_url, url, TIMEOUT) for url in urls)
    time1 = time.time()
    for future in concurrent.futures.as_completed(future_to_url):
        try:
            data = future.result()
        except Exception as exc:
            data = str(type(exc))
        finally:
            if isinstance(data, list):
                errors.append(data)
            out.append(data)
            print(str(len(out)),end="\r")

    time2 = time.time()

print(f'Took {time2-time1:.2f} s')
# Out:
# Took 119.35 s

# %% [markdown]
# # Select bottle/ctd files

# %%
to_download = []
for entry in raw_json:
    if entry['data_type'] == 'bottle' or entry['data_type'] == 'ctd':
        to_download.append(entry)

# %%
#Check total size to download
total_size = 0
for entry in to_download:
    total_size += int(entry['file_size'])
    
print(str(round(total_size / 1000000000, 2)) + ' GB')

# %% [markdown]
# Most files (8683/8798) don't have a path, what to do about these files?

# %%
empty_path_count = 0
for entry in to_download:
    if entry['file_path'] == '':
        empty_path_count += 1
empty_path_count

# %%
len(to_download)

# %%
for entry in to_download:
    if entry['file_path']:
        file_name = entry['file_name']
        file_path = entry['file_path']
        
        url = f'https://cchdo.ucsd.edu{file_path}'
        re = requests.get(url, allow_redirects=True, headers = {"X-Authentication-Token": api_key})
        open('data/' + file_name, 'wb').write(re.content)

# %%
to_download
